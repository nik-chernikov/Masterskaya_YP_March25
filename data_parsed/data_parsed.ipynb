# %%
import json

import pandas as pd

# %%
with open('../data/example/result.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
df = pd.json_normalize(data, 'messages')

# %%
df.head()
# Out:
#     id     type                 date date_unixtime               edited  \
# 0  856  message  2025-02-01T14:06:16    1738407976  2025-02-01T14:07:41
# 1  857  message  2025-02-02T14:07:55    1738494475  2025-02-03T13:05:36
# 2  858  message  2025-02-03T14:04:43    1738580683  2025-02-03T14:10:35
# 3  859  message  2025-02-04T19:02:42    1738684962  2025-02-04T19:08:41
# 4  860  message  2025-02-07T14:07:55    1738926475  2025-02-07T14:09:14
#
#   edited_unixtime                         from            from_id  \
# 0      1738408061  MANAGEMENT ALUMNI PRACTICUM  channel1586396652
# 1      1738577136  MANAGEMENT ALUMNI PRACTICUM  channel1586396652
# 2      1738581035  MANAGEMENT ALUMNI PRACTICUM  channel1586396652
# 3      1738685321  MANAGEMENT ALUMNI PRACTICUM  channel1586396652
# 4      1738926554  MANAGEMENT ALUMNI PRACTICUM  channel1586396652
#
#                                                 text  \
# 0  [{'type': 'bold', 'text': '💥'}, {'type': 'bold...
# ...
